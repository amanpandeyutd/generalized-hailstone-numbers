# %%
def con(a,b,c):
    v =[-1,0]
    x=c
    d=c+1
    v[1]=x
    for q in range(10):
        if v[1]==d:
            break
        else:
            x=x//2 if x%2==0 else a*x+b
            v.append(x)
            d=x
        
    return (v)

def pattern(a,b):
    v=[]
    count=0
    for init in range (1,11):
        v=con(a,b,init)
        for i in range(2,len(v)):
            if(v[1]==v[i]):
                count = count+1
                break
    return(count)    
        
        
def main():
    for i in range (1,11):
        for j in range(1,11):
            count= pattern(i,j)
            print("The Number of holding Patterns for pair",i,"and",j,"is: ", count)
                  
        
            
main()
# Out:
# The Number of holding Patterns for pair 1 and 1 is:  2
# The Number of holding Patterns for pair 1 and 2 is:  0
# The Number of holding Patterns for pair 1 and 3 is:  5
# The Number of holding Patterns for pair 1 and 4 is:  0
# The Number of holding Patterns for pair 1 and 5 is:  8
# The Number of holding Patterns for pair 1 and 6 is:  0
# The Number of holding Patterns for pair 1 and 7 is:  9
# The Number of holding Patterns for pair 1 and 8 is:  0
# The Number of holding Patterns for pair 1 and 9 is:  10
# The Number of holding Patterns for pair 1 and 10 is:  0
# The Number of holding Patterns for pair 2 and 1 is:  0
# The Number of holding Patterns for pair 2 and 2 is:  3
# The Number of holding Patterns for pair 2 and 3 is:  0
# The Number of holding Patterns for pair 2 and 4 is:  0
# The Number of holding Patterns for pair 2 and 5 is:  0
# The Number of holding Patterns for pair 2 and 6 is:  6
# The Number of holding Patterns for pair 2 and 7 is:  0
# ...
